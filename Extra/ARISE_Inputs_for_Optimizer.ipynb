# %%
# import packages
import pandas as pd
import datetime

# %%
# read the data
data_directory = '00_data'

df = pd.read_excel('Auftragsfolgen ohne MaschStatus-20230622.xlsx', header=0)

# %%
# 1) create new column 'Release_Date' as 'Lieferdatum_Rohmaterial' + 1 day
df['Release_Date'] = df['Lieferdatum_Rohmaterial'] + pd.Timedelta(days=1)

# 2) & 3)
# divide data by machines: Each machine gets a unique df
data = {}
for machine in df.Maschine.unique():
    data[machine] = df[df.Maschine == machine].sort_values('Start').reset_index(drop=True)
    
# filter by machine 'SL-7' and 01.01.2015 (examplary machine and date)
machine = 'SL-7'
production_start = pd.Timestamp(datetime.date(2015, 1, 1))
# get data which is released before production start and has a due data not before one day after production start
df_test = data[machine][(data[machine].Release_Date <= production_start) & (data[machine].LTermin >= production_start + pd.Timedelta(days=2))].reset_index(drop=True)

# df_test would be the dataframe that you need to pass to my optimizer.
# machine and production_start could be variables connected to buttons of you UI.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14260\1466101666.py in <module>
#      12 production_start = pd.Timestamp(datetime.date(2015, 1, 1))
#      13 # get data which is released before production start and has a due data not before one day after production start
# ---> 14 df_test = data[machine][(data[machine].Release_Date <= production_start) & (data[machine].LTermin >= production_start + pd.Timedelta(days=2))].reset_index(drop=True)
#      15
#      16 # df_test would be the dataframe that you need to pass to my optimizer.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py in __ge__(self, other)
#      58     @unpack_zerodim_and_defer("__ge__")
#      59     def __ge__(self, other):
# ---> 60         return self._cmp_method(other, operator.ge)
#      61
#      62     # -------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# -> 5623             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5624
#    5625         return self._construct_result(res_values, name=res_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     281
#     282     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     284
#     285     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'Timestamp'

# %%
df_test
# Out:
#        AKNR  TeilNr  SchrittNr           Fefco_Teil ArtNr_Teil  ID_Druck  \
# 0      3272       1          1  0110 (Fert.-Riller)      10141         0
# 1      3349       1          1             0410 man      11070         1
# 2      3340       1          1             0410 man      10962         1
# 3      3543       1          1             0411 man      10304         1
# 4      3331       1          1             0410 man      10967         1
# ...     ...     ...        ...                  ...        ...       ...
# 5493   4513       1          1             0410 man      11678         1
# 5494   4959       1          1             0950 man      11850         1
# 5495  38919       2          1               0300/B    16417/B         1
# 5496  38919       2          1               0300/D    16417/D         1
# 5497  46832       1          1             0410 man      11317         1
#
#       Druckflaeche  Bogen_Laenge_Brutto  Bogen_Breite_Brutto Maschine  ...  \
# 0              NaN               2033.0               1855.0     SL-7  ...
# 1             0.10               1762.0               1132.0     SL-7  ...
# 2             0.10               1986.0                995.0     SL-7  ...
# 3             0.05               2200.0               2071.0     SL-7  ...
# 4             0.10               1406.0               1674.0     SL-7  ...
# ...            ...                  ...                  ...      ...  ...
# 5493          0.10               1076.0                755.0     SL-7  ...
# 5494          0.02               1704.0               1245.0     SL-7  ...
# 5495          0.01               2145.0               1252.0     SL-7  ...
# 5496          0.10               2165.0               1286.0     SL-7  ...
# 5497          0.10               1195.0                874.0     SL-7  ...
#
#       Menge_Ist                                          Bemerkung  \
# 0          1000                Stanzwerkzeug Nr. 600 liegt am SL 9
# 1           630  Druckfarbe : schwarz   Klischee liegt in Kiste 18
# 2           800  Druckfarbe : schwarz   Klischee liegt in Kiste 18
# 3          1190                                                NaN
# 4           600  Druckfarbe : schwarz   Klischee liegt in Kiste 18
# ...         ...                                                ...
# 5493       3400                                                NaN
# 5494          0                                 Druck : Nr. 613056
# 5495        100  Druck: Interseroh-DSI ( in Kiste 6 ) mittig au...
# 5496        100  Druck: Interseroh-DSI mittig auf die große Flä...
# 5497       1207  Klischee Nr. 1285  Druckfarbe: schwarz  FSC-Nr...
#
#                       LTermin  KndNr          Suchname  \
# 0     2014-01-09 00:00:00.000  11662              LEBO
# 1     2014-01-08 00:00:00.000  12300               BMG
# 2     2014-01-08 00:00:00.000  12300               BMG
# 3     2014-01-08 00:00:00.000  11910              HUGA
# 4     2014-01-08 00:00:00.000  12300               BMG
# ...                       ...    ...               ...
# 5493  2014-01-14 00:00:00.000  12516  STEENS GROUP A/S
# 5494  2014-01-27 00:00:00.000  10960  THIELEMEYER GMBH
# 5495  2016-02-12 00:00:00.000  13177  DOMINA VERTRIEBS
# 5496  2016-02-12 00:00:00.000  13177  DOMINA VERTRIEBS
# 5497  2016-09-09 00:00:00.000  12516  STEENS GROUP A/S
#
#       Lieferdatum_Rohmaterial  BE_Erledigt                    Start  \
# 0                  2014-01-03            1  2014-01-06 11:49:30.000
# 1                  2014-01-02            1  2014-01-07 08:11:49.000
# 2                  2014-01-02            1  2014-01-07 09:23:51.000
# 3                  2014-01-04            1  2014-01-07 20:26:37.000
# 4                  2014-01-03            1  2014-01-08 06:15:45.000
# ...                       ...          ...                      ...
# 5493               2014-01-14            1                      NaN
# 5494               2014-01-22            1                      NaN
# 5495               2016-02-08            1                      NaN
# 5496               2016-02-08            1                      NaN
# 5497               2016-08-30            1                      NaN
#
#                          Ende  Release_Date
# 0     2014-01-06 13:25:07.000    2014-01-04
# 1     2014-01-07 08:31:44.000    2014-01-03
# 2     2014-01-07 09:53:14.000    2014-01-03
# 3     2014-01-07 20:31:31.000    2014-01-05
# 4     2014-01-08 07:11:45.000    2014-01-04
# ...                       ...           ...
# 5493                      NaN    2014-01-15
# 5494                      NaN    2014-01-23
# 5495                      NaN    2016-02-09
# 5496                      NaN    2016-02-09
# 5497                      NaN    2016-08-31
#
# [5498 rows x 29 columns]
